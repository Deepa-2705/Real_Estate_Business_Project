# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('D:/Real_State_Business_Project/datasets/flats_cleaned.csv')
houses = pd.read_csv('D:/Real_State_Business_Project/datasets/house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                       property_name property_type                  society  \
# 0     3 BHK Flat in Sector 36 Sohna          flat  signature global park 4
# 1  3 BHK Flat in Sector 102 Gurgaon          flat     emaar gurgaon greens
# 2         3 BHK Flat in DLF Phase 4          flat         dlf regency park
# 3   4 BHK Flat in Sector 69 Gurgaon          flat             tulip violet
# 4  3 BHK Flat in Sector 102 Gurgaon          flat   emaar imperial gardens
#
#    price  price_per_sqft    area  \
# 0   0.72          6660.0  1081.0
# 1   1.42          8606.0  1650.0
# 2   2.35         13224.0  1777.0
# 3   3.05          9664.0  3156.0
# 4   1.98          9900.0  2000.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 1081(100.43 sq.m.)        3         2
# 1  Super Built up area 1650(153.29 sq.m.)Carpet a...        3         3
# 2  Super Built up area 1777(165.09 sq.m.)Built Up...        3         4
# ...

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.to_csv('D:/Real_State_Business_Project/datasets/gurgaon_properties.csv',index=False)
