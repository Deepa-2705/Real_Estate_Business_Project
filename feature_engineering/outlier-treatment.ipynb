# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('D:/Real_State_Business_Project/datasets/gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat  signature global park 4   sector 36   0.72          6660.0
# 1          flat     emaar gurgaon greens  sector 102   1.42          8606.0
# 2          flat         dlf regency park   sector 28   2.35         13224.0
# 3          flat             tulip violet   sector 69   3.05          9664.0
# 4          flat   emaar imperial gardens  sector 102   1.98          9900.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1081.0             Super Built up area 1081(100.43 sq.m.)        3
# 1  1650.0  Super Built up area 1650(153.29 sq.m.)Carpet a...        3
# 2  1777.0  Super Built up area 1777(165.09 sq.m.)Built Up...        3
# 3  3156.0              Super Built up area 3156(293.2 sq.m.)        4
# 4  2000.0                   Carpet area: 2000 (185.81 sq.m.)        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
# outliers on the basis of price column
sns.distplot(df['price'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\2797181776.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 3285         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 3491         house                                        independent
# 1853         house                                     dlf city plots
# 151          house                                        independent
# 3519         house                                   suncity township
# 1212         house                             emaar the palm springs
# 1378         house                                        independent
# 2403         house                                 vipul tatvam villa
# 3437         house                                     dlf city plots
# 3203         house                                        independent
# 1729         house                             luxury dlf city floors
# 3305         house                                 vipul tatvam villa
# ...

# %%
# on the basis of price col we can say that there are some genuine outliers but there are some data erros as well

# %% [markdown]
# ### Price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
# correct the data error
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\1828812317.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society           sector  price  \
# 151          house                   independent        sector 26  26.00
# 423          house                           nul        sector 28  12.50
# 1212         house        emaar the palm springs        sector 54  24.00
# 1790         house                  malibu towne        sector 47   8.50
# 1853         house                dlf city plots        sector 26  26.00
# 2084         house                   independent        sector 25  16.00
# 2225         house                unitech escape        sector 50  10.80
# 2267         house            emaar mgf marbella        sector 66  18.00
# 2660         house        emaar the palm springs        sector 54  14.00
# 3018         house                   independent        sector 26  14.75
# 3026         house            cloudnine cottages  sohna road road   5.50
# 3325          flat                unitech vistas        sector 70   9.00
# ...

# %%
# remove above 13 values of outliers
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ### Area

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 259           flat            ramsons kshitij   sector 95   0.31
# 492          house                independent   sector 50   5.00
# 579           flat  signature global solera 2  sector 107   0.51
# 776           flat          hcbs sports ville  sohna road   0.35
# 1434          flat      signature the roselia   sector 95   0.45
#
#       price_per_sqft      area                           areaWithType  \
# 259              5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 492            232.0  215517.0             Plot area 2(1011.71 sq.m.)
# 579              9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 776              4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 1434             7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 259         2         2       1       1.0  North-East  Relatively New
# ...

# %%
# remove this outlier value
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)

# 1207, 1773, 3118, 578, 2607, 3493, 1668, 2814, 3303
# Out:
#      property_type                    society           sector  price  \
# 1207         house                independent        sector 26  18.40
# 3727         house  ganpati heights apartment        sector 13   1.25
# 1773          flat                 rof ananda        sector 95   0.38
# 3118          flat                 rof ananda        sector 95   0.38
# 425          house      dlf city plot phase 4        sector 28  13.00
# 578           flat              pyramid elite        sector 86   0.46
# 2607          flat                 rof ananda        sector 95   0.33
# 3493          flat      signature the serenas       sohna road   0.28
# 1818         house                independent        sector 25   7.30
# 1668          flat            ramsons kshitij        sector 95   0.24
# 2814          flat                 rof ananda        sector 95   0.21
# 2050         house                independent        sector 57   6.25
# ...

# %%
df.drop(index=[1207, 1773, 3118, 578, 2607, 3493, 1668, 2814, 3303], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 3727         house  ganpati heights apartment        sector 13   1.25
# 425          house      dlf city plot phase 4        sector 28  13.00
# 1818         house                independent        sector 25   7.30
# 2050         house                independent        sector 57   6.25
# 1638         house                independent        sector 43   5.50
# 3525          flat                 godrej air        sector 85   2.50
# 2677         house       unitech aspen greens        sector 50   6.95
# 3310          flat                godrej icon       sector 88a   1.75
# 3491         house                independent        sector 43  27.50
# 644           flat             m3m golfestate        sector 65  13.20
# 2684         house                independent  sohna road road   5.50
#
#       price_per_sqft     area  \
# 3727           151.0  82781.0
# 425           1992.0  65261.0
# 1818          1560.0  46795.0
# ...

# %%
df.loc[3727,'area'] = 115*9
df.loc[425,'area'] = 7250
df.loc[1818,'area'] = 5800
df.loc[2050,'area'] = 2660
df.loc[1638,'area'] = 2850
df.loc[3525,'area'] = 1812
df.loc[2677,'area'] = 2160
df.loc[3310,'area'] = 1175

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      1950.357005
# std       1215.707897
# min        145.000000
# 25%       1260.000000
# 50%       1747.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# ### Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.333609
# std         1.830035
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 1339         house                  independent   sector 54   5.00
# 1711         house                  independent   sector 43   4.50
# 3573         house                  independent  sector 17a   3.93
# 2968         house                  independent  sector 17a   3.87
# 1717         house                  independent   sector 54   5.50
# 1613         house                private house   sector 55   7.05
# 2880         house                  independent   sector 56  12.39
# 1973         house                  independent   sector 55   9.19
# 939          house                  independent   sector 43  13.50
# 3437         house               dlf city plots   sector 26  20.00
# 1531         house                  independent   sector 11   4.50
# 1729         house       luxury dlf city floors   sector 26  20.00
# 2975         house                  independent   sector 40  12.00
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3588.000000
# mean        3.203735
# std         1.393968
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ### Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 2280         house  adani brahma samsara  sector 60  18.02         28200.0
# 2416         house           independent  sector 39   7.00         10000.0
# 3071         house           independent  sector 24  11.00         28902.0
#
#         area                                       areaWithType  bedRoom  \
# 2280  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 2416  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
# 3071  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 2280        12      3+       3.0  North-East  Relatively New
# 2416        11      3+       4.0  South-East  Relatively New
# 3071        11      3+       3.0        East    Old Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat  signature global park 4   sector 36   0.72          6660.0
# 1          flat     emaar gurgaon greens  sector 102   1.42          8606.0
# 2          flat         dlf regency park   sector 28   2.35         13224.0
# 3          flat             tulip violet   sector 69   3.05          9664.0
# 4          flat   emaar imperial gardens  sector 102   1.98          9900.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1081.0             Super Built up area 1081(100.43 sq.m.)        3
# 1  1650.0  Super Built up area 1650(153.29 sq.m.)Carpet a...        3
# 2  1777.0  Super Built up area 1777(165.09 sq.m.)Built Up...        3
# 3  3156.0              Super Built up area 3156(293.2 sq.m.)        4
# 4  2000.0                   Carpet area: 2000 (185.81 sq.m.)        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %% [markdown]
# ### super built up area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 209           flat       krrish provence estate  gwal pahari    7.5
# 1721          flat  bestech park view grand spa    sector 81    4.7
#
#       price_per_sqft     area                             areaWithType  \
# 209           7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
# 1721          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 209         5         6      3+      23.0  North-East  Relatively New
# 1721        4         4      3+      19.0       North  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 209               10000.0            NaN          NaN           0
# 1721               6926.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# ### built up area

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 3491         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  floorNum  \
# 3491  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 3491  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 3491          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# 3491                0            42

# %% [markdown]
# ### carpet area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 644           flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
# 3525          flat      godrej air  sector 85    2.5          1379.0   1812.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 644   Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
# 3525  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 644        North      Moderately Old                  NaN            NaN
# 3525  North-East  Under Construction                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 644       11000.0           0             1           0           0       0
# 3525      18122.0           1             0           0           1       1
#
#       furnishing_type  luxury_score
# ...

# %%
df.loc[3525,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#     property_type         society     sector  price  price_per_sqft     area  \
# 644          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                            areaWithType  bedRoom  bathroom balcony  floorNum  \
# 644  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#     facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 644  North  Moderately Old                  NaN            NaN      11000.0
#
#      study room  servant room  store room  pooja room  others  \
# 644           0             1           0           0       0
#
#      furnishing_type  luxury_score
# 644                1            60

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat  signature global park 4   sector 36   0.72          6660.0
# 1          flat     emaar gurgaon greens  sector 102   1.42          8606.0
# 2          flat         dlf regency park   sector 28   2.35         13224.0
# 3          flat             tulip violet   sector 69   3.05          9664.0
# 4          flat   emaar imperial gardens  sector 102   1.98          9900.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1081.0             Super Built up area 1081(100.43 sq.m.)        3
# 1  1650.0  Super Built up area 1650(153.29 sq.m.)Carpet a...        3
# 2  1777.0  Super Built up area 1777(165.09 sq.m.)Built Up...        3
# 3  3156.0              Super Built up area 3156(293.2 sq.m.)        4
# 4  2000.0                   Carpet area: 2000 (185.81 sq.m.)        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df.shape
# Out:
# (3588, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat  signature global park 4   sector 36   0.72          6660.0
# 1          flat     emaar gurgaon greens  sector 102   1.42          8606.0
# 2          flat         dlf regency park   sector 28   2.35         13225.0
# 3          flat             tulip violet   sector 69   3.05          9664.0
# 4          flat   emaar imperial gardens  sector 102   1.98          9900.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1081.0             Super Built up area 1081(100.43 sq.m.)        3
# 1  1650.0  Super Built up area 1650(153.29 sq.m.)Carpet a...        3
# 2  1777.0  Super Built up area 1777(165.09 sq.m.)Built Up...        3
# 3  3156.0              Super Built up area 3156(293.2 sq.m.)        4
# 4  2000.0                   Carpet area: 2000 (185.81 sq.m.)        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 306          house                   independent   sector 55    5.0
# 861          house  sushant lok 1 builder floors   sector 43   13.0
# 1294         house                   independent   sector 26   19.0
# 1826         house                   independent   sector 28   12.0
# 2372         house                dlf city plots   sector 26   19.0
# 2603         house                   independent   sector 43    9.5
# 3203         house                   independent   sector 26   20.0
# 3633         house                   independent  sector 105    9.9
# 3679         house                   independent   sector 25   13.0
#
#       price_per_sqft    area  \
# 306          44444.0  1125.0
# 861          48148.0  2700.0
# 1294         42222.0  4500.0
# 1826         42194.0  2844.0
# 2372         42054.0  4518.0
# 2603         42222.0  2250.0
# 3203         44444.0  4500.0
# 3633         49500.0  2000.0
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# 250.5

# %%
df[(df['area']/df['bedRoom'])<250].sample(5)
# Out:
#      property_type                     society      sector  price  \
# 331           flat  central park flower valley   sector 33   1.40
# 2614         house                  madan puri    sector 7   0.75
# 3622         house                 independent    sector 7   1.16
# 2332          flat     signature global solera  sector 107   0.29
# 3675          flat     signature global solera  sector 107   0.52
#
#       price_per_sqft   area                          areaWithType  bedRoom  \
# 331          21538.0  650.0  Super Built up area 650(60.39 sq.m.)        3
# 2614         12500.0  600.0            Plot area 600(55.74 sq.m.)        3
# 3622         11717.0  990.0        Carpet area: 110 (91.97 sq.m.)        5
# 2332          5930.0  489.0        Carpet area: 489 (45.43 sq.m.)        2
# 3675          8062.0  645.0        Carpet area: 645 (59.92 sq.m.)        3
#
#       bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df['area_room_ratio']=df['area']/df['bedRoom']

# %%
(df[df['area_room_ratio']<250])['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     47
# 3     33
# 5     28
# 6     17
# 4     17
# 9     15
# 8     12
# 10     8
# 7      8
# Name: count, dtype: int64

# %%
df=df[df['area_room_ratio']>100]

# %%
outliers_df=df[(df['area_room_ratio']<250) & (df['bedRoom']>3)]

# %%
outliers_df['bedRoom']=round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\3359844150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom']=round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio']=df['area']/df['bedRoom']
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_11108\2419531321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_room_ratio']=df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom']>4)]
# Out:
#      property_type               society            sector  price  \
# 197          house           independent  sector 3 phase 2   0.85
# 650          house           independent           manesar   1.10
# 748          house           independent         sector 17   0.32
# 1198         house           independent         sector 11   3.50
# 1847         house           independent          sector 2   0.98
# 1887         house              shivpuri          sector 7   2.80
# 2502         house  bhim nagar, sector 6          sector 6   0.85
# 2547         house           independent           manesar   0.80
# 2701         house           independent  sector 3 phase 2   1.10
# 3206         house           independent         sector 12   2.50
# 3215         house           independent        sector 105   1.10
# 3590         house           independent         sector 12   0.65
# 3622         house           independent          sector 7   1.16
#
#       price_per_sqft    area  \
# ...

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom']>4)].shape
# Out:
# (13, 24)

# %%
df.shape
# Out:
# (3568, 24)

# %%
df=df[~((df['area_room_ratio']<250) & (df['bedRoom']>4))]

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df.shape
# Out:
# (3555, 24)

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat  signature global park 4   sector 36   0.72          6660.0
# 1          flat     emaar gurgaon greens  sector 102   1.42          8606.0
# 2          flat         dlf regency park   sector 28   2.35         13225.0
# 3          flat             tulip violet   sector 69   3.05          9664.0
# 4          flat   emaar imperial gardens  sector 102   1.98          9900.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1081.0             Super Built up area 1081(100.43 sq.m.)        3
# 1  1650.0  Super Built up area 1650(153.29 sq.m.)Carpet a...        3
# 2  1777.0  Super Built up area 1777(165.09 sq.m.)Built Up...        3
# 3  3156.0              Super Built up area 3156(293.2 sq.m.)        4
# 4  2000.0                   Carpet area: 2000 (185.81 sq.m.)        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
df.to_csv('D:/Real_State_Business_Project/datasets/gurgaon_properties_outlier_treated.csv',index=False)
